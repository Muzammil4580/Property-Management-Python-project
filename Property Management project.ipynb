# %%
# import pandas
import csv
print("\t\tWelcome To property Management System")

def Main():
    print("\n1.poperty registration")
    print("\n2.property place")
    print("\n3.property record") 
    print("\n4.Exit")
    a = int(input("Enter the number from Menu to proceed"))
    if a==1:
        print("\n**poperty registration**")
        property()
    elif a==2:
        print("\n**property place**")
        Place()
    elif a==3:
        print("\n**property record**")
        Record()
    elif a==0:
        quit()
    return()

def property():
    while 1:
        print("\n1.Insert \n2.Show \n3.Delete \n4.Update \n.5.Main Menu")
        b = int(input("Enter the number from Menu to proceed"))
        if b==1:
            from csv import writer
            a = str(input("Enter property owner"))
            b = int(input("Enter CNIC "))
            c = str(input("Enter Prperty size: "))
            d = str(input("Enter the location: "))
            list_data = [a, b, c, d]
            with open('usman.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif b==2:
            s = pandas.read_csv('usman.csv')
            print(s)
        elif b==3:
            n = int(input("Enter the CNIC number whose data you want to delete:"))
            v = pandas.read_csv('usman.csv')
            d = v[: 2]
            d.set_index('registration ID', inplace=True)
            d = d.drop(n)
            print(d)
        elif b==4:
            n = int(input("Enter the number of row in which replacement is made: "))
            N = str(input("Enter the name of column in which you want replacement"))
            r = str(input("Enter the new thing"))
            cf = pandas.read_csv("usman.csv")
            cf.loc[n, N] = r
            cf.to_csv("usman.csv", index=False)
            print(cf)
        else:
            Main()
####################################################################


#*************************
def Place():
    while 1:
        print("\n1.Insert \n2.Show \n3.Delete \n4.Update \n.5.Main Menu")
        c = int(input("Enter the number from Menu to proceed"))
        if c==1:
            from csv import writer
            a = str(input("Enter property place"))
            b = int(input("Enter registration id "))
            c = str(input("Enter Prperty owner: "))
            list_data = [a, b, c]
            with open('usman1.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif c==2:
            s = pandas.read_csv('usman1.csv')
            print(s)
        elif c==3:
            n = int(input("Enter the id number whose data you want to delete:"))
            v = pandas.read_csv('usman1.csv')
            d = v[: 2]
            d.set_index('registration ID', inplace=True)
            d = d.drop(n)
            print(d)
        elif c==4:
            n = int(input("Enter the number of row in which replacement is made: "))
            N = str(input("Enter the name of column in which you want replacement"))
            r = str(input("Enter the new thing"))
            cf = pandas.read_csv("usman1.csv")
            cf.loc[n, N] = r
            cf.to_csv("usman1.csv", index=False)
            print(cf)
        else:
            Main()
#*******************

#$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
def Record():
    while 1:
        print("\n1.Insert \n2.Show \n3.Delete \n4.Update \n.5.Main Menu")
        d = int(input("Enter the number from Menu to proceed"))
        if d==1:
            from csv import writer
            a = int(input("Enter the ID number"))
            b = str(input("Enter property owner"))
            c = int(input("Enter CNIC "))
            d = str(input("Enter Prperty size: "))
            e = str(input("Enter the location: "))
            list_data = [a, b, c, d, e]
            with open('arshad.csv', 'a', newline='') as f_object:
                writer_object= writer(f_object)
                writer_object.writerow(list_data)
                f_object.close()
        elif d==2:
            s = pandas.read_csv('arshad.csv')
            print(s)
        elif d==3:
            n = int(input("Enter the ID number whose data you want to delete:"))
            v = pandas.read_csv('arshad.csv')
            d = v[: 2]
            d.set_index('ID', inplace=True)
            d = d.drop(n)
            print(d)
        elif d==4:
            n = int(input("Enter the number of row in which replacement is made: "))
            N = str(input("Enter the name of column in which you want replacement"))
            r = str(input("Enter the new thing"))
            cf = pandas.read_csv("arshad.csv")
            cf.loc[n, N] = r
            cf.to_csv("arshad.csv", index=False)
            print(cf)
        else:
            Main()
Main()
